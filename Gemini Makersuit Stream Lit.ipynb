# %%
# !pip install google-generativeai

# %%
import os
import google.generativeai as genai
api_key="AIzaSyDOZ-AQe8zo61YuqG4Bo26NGNehepgwLeM"
genai.configure(api_key=api_key)
#we are accessing google ai gemini ai model
#with our api key

# %%
for m in genai.list_models():
  print(m.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision
# models/embedding-001
# models/aqa

# %%
model=genai.GenerativeModel("gemini-pro")
model
# Out:
#  genai.GenerativeModel(
#    model_name='models/gemini-pro',
#    generation_config={}.
#    safety_settings={}
# )

# %%
response=model.generate_content("List of top 5 indian cricketers")
print(response.text)
# Out:
# 1. **Sachin Tendulkar**
# 2. **Virat Kohli**
# 3. **Sourav Ganguly**
# 4. **Rahul Dravid**
# 5. **Anil Kumble**

# %%
response=model.generate_content("List of top 5 indian cricketers,why they are top in list")
print(response.text)
# Out:
# **Top 5 Indian Cricketers**
#
# 1. **Sachin Tendulkar:**
#    - Known as the "God of Cricket" for his exceptional batting skills.
#    - Holds numerous batting records, including the most runs scored in international cricket (18,426).
#    - Known for his elegant technique, consistency, and mental resilience.
#
# 2. **Virat Kohli:**
#    - Current captain of the Indian cricket team and one of the modern-day greats.
#    - Known for his aggressive batting style and exceptional chase abilities.
#    - Has scored over 25,000 international runs and is ranked among the top batsmen in the world.
#
# 3. **MS Dhoni:**
#    - Former captain of the Indian team and one of the most successful captains in cricket history.
#    - Known for his calm demeanor, strategic thinking, and exceptional wicket-keeping skills.
#    - Led India to victories in the 2007 T20 World Cup, 2011 Cricket World Cup, and 2013 ICC Champions Trophy.
#
# 4. **Kapil Dev:**
# ...

# %%
response=model.generate_content("Write a poen on kid")
print(response.text)
# Out:
# **Ode to a Little One**
#
# Tiny hands and rosy cheeks,
# Eyes like stars, a smile that speaks.
# A bundle of joy, so small and dear,
# A precious gift, beyond compare.
#
# With every step, a newfound grace,
# Each word a melody, a chase.
# Imagination takes flight so bold,
# A world of wonder, stories yet untold.
#
# Curiosity sparkles in your eyes,
# A thirst for knowledge, never dies.
# You dance with joy, a carefree soul,
# Your laughter fills the air, making whole.
#
# Your tiny heart, so pure and true,
# A vessel of love, where seeds of virtue grew.
# You teach us patience, kindness, grace,
# The beauty of life's gentle pace.
#
# In your embrace, we find our joy,
# A timeless bond, devoid of alloy.
# For in your eyes, we see our own,
# A reflection of our hopes and dreams sown.
#
# O little one, our precious child,
# May your path be filled with joy untold.
# May every step you take inspire,
# And every moment set your soul afire.
#
# For in your tiny being, we find,
# ...

# %% [markdown]
# #Image model

# %%
from PIL import Image  #package name:pillow

# %%
img=Image.open("/content/Garden image.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
import google.generativeai as genai
api_key="AIzaSyDOZ-AQe8zo61YuqG4Bo26NGNehepgwLeM"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
prompt="what are the objects in the given model"

response=model.generate_content([prompt,img])
print(response.text)
# Out:
#  There are four objects in the given model. They are:
# 1. A woman
# 2. A basket
# 3. A field of tea plants
# 4. A hat

# %%
import google.generativeai as genai
api_key="AIzaSyDOZ-AQe8zo61YuqG4Bo26NGNehepgwLeM"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
prompt="caption the image"

response=model.generate_content([prompt,img])
print(response.text)
# Out:
#  A woman is working in a tea plantation. She is wearing a traditional Chinese dress and is carrying a basket on her back. The woman is smiling and looks happy. The background is a lush green tea plantation.

# %%
import google.generativeai as genai
api_key="AIzaSyDOZ-AQe8zo61YuqG4Bo26NGNehepgwLeM"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
prompt="write a poem on the above image"

response=model.generate_content([prompt,img])
print(response.text)
# Out:
#  The tea leaves are green,
# The tea leaves are fresh,
# The tea leaves are picked,
# By the nimble hands of the tea pluckers.
#
# The tea leaves are withered,
# The tea leaves are rolled,
# The tea leaves are fired,
# And the tea leaves are ready to be brewed.
#
# The tea leaves are steeped in hot water,
# The tea leaves release their flavor,
# The tea leaves release their aroma,
# And the tea is ready to be enjoyed.
#
# The tea is a gift from nature,
# The tea is a gift from the earth,
# The tea is a gift from the sun,
# And the tea is a gift from the rain.
#
# The tea is a gift from the tea pluckers,
# The tea is a gift from the tea farmers,
# The tea is a gift from the tea makers,
# And the tea is a gift from the tea drinkers.
#
# The tea is a gift to be shared,
# The tea is a gift to be enjoyed,
# The tea is a gift to be savored,
# And the tea is a gift to be cherished.

# %%
from PIL import Image  #package name:pillow
img=Image.open("/content/Garden image.jpg")

import google.generativeai as genai
api_key="AIzaSyDOZ-AQe8zo61YuqG4Bo26NGNehepgwLeM"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
prompt="caption the image"

response=model.generate_content([prompt,img])
print(response.text)

# %% [markdown]
# #create application

# %%
# !pip install streamlit
# !npm install localtunel
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 37.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...
# npm ERR! code E404
# npm ERR! 404 Not Found - GET https://registry.npmjs.org/localtunel - Not found
# npm ERR! 404
# npm ERR! 404  'localtunel@latest' is not in the npm registry.
# npm ERR! 404 You should bug the author to publish it (or use the name yourself!)
# npm ERR! 404
# npm ERR! 404 Note that you can also install from a
# ...

# %%
# %%writefile app.py
###################Import the required packagrs #########
import streamlit as st
import google.generativeai as genai
from PIL import Image

#provide your api key ########
api_key="AIzaSyDOZ-AQe8zo61YuqG4Bo26NGNehepgwLeM"
genai.configure(api_key=api_key)

##choose the heading ############
st.header("Image analytics")


############upload a file ########
uploaded_file=st.file_uploader("Upload an image",type=["png","jpg","jpeg"])

if uploaded_file is not None:
  st.image(Image.open(uploaded_file))

  ######what you want to ask###########
  prompt=st.text_input("Enter the text")

  #####use genai skill ##########

  if st.button("GET RESPONSE"):
    img=Image.open(uploaded_file)
    model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
    response=model.generate_content([prompt,img])
    st.markdown(response.text)
# Out:
# Writing app.py

# %%
# !streamlit run /content/app.py & npx localtunnel --port  8501  & curl ipv4.icanhazip.com
# Out:
# 104.196.111.136
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://104.196.111.136:8501
#
# npx: installed 22 in 2.391s
# your url is: https://flat-feet-wash.loca.lt
#   Stopping...
